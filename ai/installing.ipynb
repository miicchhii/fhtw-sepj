# %%
import sys, site, pkgutil, platform
print("Python:", sys.version)
print("Exe   :", sys.executable)
print("Paths :", "\n  - " + "\n  - ".join(site.getsitepackages() + [site.getusersitepackages()]))
print("Has 'tree'?", pkgutil.find_loader("tree") is not None)
print("OS:", platform.platform())
# Out:
# Python: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# Exe   : C:\Users\Michael\Documents\GODOT\fhtw-sepj-refactor\ai\.venv\Scripts\python.exe
# Paths :
#   - C:\Users\Michael\Documents\GODOT\fhtw-sepj-refactor\ai\.venv
#   - C:\Users\Michael\Documents\GODOT\fhtw-sepj-refactor\ai\.venv\lib\site-packages
#   - C:\Users\Michael\AppData\Roaming\Python\Python310\site-packages
# Has 'tree'? True
# OS: Windows-10-10.0.26200-SP0
